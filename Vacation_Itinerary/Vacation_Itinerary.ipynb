# %% [markdown]
# ## Deliverable 3. Create a Travel Itinerary Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps
gmaps.configure(api_key=g_key)

# %%
# 1. Read the WeatherPy_vacation.csv into a DataFrame.
vacation_df = pd.read_csv("WeatherPy_vacation.csv")
vacation_df
# Out:
#      City_ID             City Country  Max Temp Current Description    Lat  \
# 0          0         kalmunai      LK     81.27     overcast clouds   7.42
# 1          1     san jeronimo      PE     50.00          light rain -13.65
# 2          2  bambous virieux      MU     81.00         shower rain -20.34
# 3          3           atuona      PF     80.35           clear sky  -9.80
# 4          4           hobart      AU     69.80    scattered clouds -42.88
# ..       ...              ...     ...       ...                 ...    ...
# 556      556              ler      NO     39.20         shower rain  63.20
# 557      557    prince george      CA     35.01          light rain  53.92
# 558      558          grafton      AU     89.60          few clouds -29.69
# 559      559          merauke      ID     87.35       moderate rain  -8.49
# 560      560       hambantota      LK     89.60       broken clouds   6.12
#
#         Lng                             Hotel Name
# 0     81.82                               VS Villa
# 1    -73.37                  La Mansion Casa Hotel
# 2     57.76                         Casa Tia Villa
# 3   -139.03                            Villa Enata
# 4    147.33  St Ives Hobart Accommodation Tasmania
# ..      ...                                    ...
# 556   10.30              Motel Pokoje Do Wynajecia
# 557 -122.75   Canadas Best Value Inn Prince George
# 558  152.93          Glenwood Tourist Park & Motel
# 559  140.40                 Swiss-Belhotel Merauke
# 560   81.12                            Bungalow 63
#
# [561 rows x 8 columns]

# %%
pref_cities_df = vacation_df.loc[(vacation_df["Country"] == "CA")]
pref_cities_df
# Out:
#      City_ID                     City Country  Max Temp Current Description  \
# 38        38            sioux lookout      CA     14.00       broken clouds
# 49        49              tuktoyaktuk      CA    -11.20          light snow
# 54        54                  iqaluit      CA    -14.01           clear sky
# 83        83               whitehorse      CA     34.00       broken clouds
# 103      103                 thompson      CA      6.80          light snow
# 107      107                   kenora      CA     15.80       broken clouds
# 108      108            moose factory      CA     19.40          light snow
# 114      114              yellowknife      CA      9.00          light snow
# 133      133              pangnirtung      CA    -21.17     overcast clouds
# 134      134               port hardy      CA     44.60          light rain
# 143      143                  dauphin      CA     15.80     overcast clouds
# 150      150                geraldton      CA     12.20          light snow
# 157      157                   torbay      CA     34.00     overcast clouds
# 187      187                     mayo      CA      6.80     overcast clouds
# 192      192  saint-michel-des-saints      CA     21.96                snow
# 194      194              temiscaming      CA     34.00          light snow
# 197      197                   dryden      CA     14.00    scattered clouds
# 206      206           saint-philippe      CA     32.00          light snow
# 213      213                 la tuque      CA     21.31          light snow
# 265      265                parrsboro      CA     28.40     overcast clouds
# 279      279                eganville      CA     32.00          light snow
# 289      289                bonavista      CA     33.01          light snow
# 330      330              ferme-neuve      CA     26.46          light snow
# 345      345              forestville      CA     19.40    scattered clouds
# 357      357             murdochville      CA     11.48       broken clouds
# 370      370                   inuvik      CA    -14.80          light snow
# 371      371              clyde river      CA    -23.80           clear sky
# 373      373             norman wells      CA    -20.20       broken clouds
# 376      376                marystown      CA     30.00    scattered clouds
# 382      382                shelburne      CA     35.60          light snow
# 398      398             port-cartier      CA      9.00           clear sky
# 412      412                  kitimat      CA     36.00       moderate rain
# 419      419                sept-iles      CA      9.00           clear sky
# 453      453                  husavik      CA      7.00          few clouds
# 463      463                flin flon      CA     10.17       broken clouds
# 493      493                hay river      CA     14.00          few clouds
# 496      496              fort nelson      CA      3.20       broken clouds
# 511      511           saint-augustin      CA     30.99          light snow
# 514      514                  halifax      CA     30.99       broken clouds
# 530      530          haines junction      CA     25.20          light snow
# 538      538                  quesnel      CA     33.80          light rain
# 557      557            prince george      CA     35.01          light rain
#
#        Lat     Lng                                         Hotel Name
# 38   50.10  -91.92                              Knobby's Fly-In Camps
# 49   69.44 -133.03                               End of The Road Ltd.
# 54   63.75  -68.52                                      Frobisher Inn
# 83   60.72 -135.06         The Sternwheeler Hotel & Conference Centre
# 103  55.74  -97.86                                    Burntwood Hotel
# 107  49.76  -94.48         Clarion Lakeside Inn and Conference Centre
# 108  51.26  -80.61                             Cree Village Eco Lodge
# 114  62.45 -114.38                                 The Explorer Hotel
# 133  66.15  -65.72                                      Kilabuk Lodge
# 134  50.70 -127.42                                        Airport Inn
# 143  51.15 -100.04                                Canway Inn & Suites
# 150  49.72  -86.95                           Victoria Bed & Breakfast
# 157  47.66  -52.73                                        See The Sea
# 187  63.59 -135.90                  Gold and Galena Bed and Breakfast
# 192  46.68  -73.92                              Motel Du Mont trinity
# 194  46.72  -79.10                                 Auberge Canadienne
# 197  49.79  -92.84                         Holiday Inn Express Dryden
# 206  45.36  -73.48                                   Camping St-Andre
# 213  47.44  -72.79                                   The Gite du Parc
# 265  45.41  -64.33                                Gillespie House Inn
# 279  45.54  -77.10                                           Egan Inn
# 289  48.65  -53.11                           Abbott's Bed & Breakfast
# 330  46.70  -75.45                     Pourvoirie Club Fontbrune Ltee
# 345  48.74  -69.09                           Camping de la Baie Verte
# 357  48.96  -65.49                 Les Suites économique Murdochville
# 370  68.36 -133.71                                    Nova Inn Inuvik
# 371  70.47  -68.59                                        Qamaq Hotel
# 373  65.28 -126.83                                     Heritage Hotel
# 376  47.17  -55.16                Marystown Hotel & Convention Centre
# 382  44.08  -80.20                            The Retreat at the Farm
# 398  50.03  -66.88                                        Le Q'Artier
# 412  54.02 -128.69  Kingfish Westcoast Adventures Ltd. Kitimat Est...
# 419  50.20  -66.38                                        Comfort Inn
# 453  50.56  -96.99                                Idle Wheels RV Park
# 463  54.77 -101.88                             Victoria Inn Flin Flon
# 493  60.82 -115.79                               Ptarmigan Inn Hotels
# 496  58.81 -122.69                              The Fort Nelson Hotel
# 511  45.63  -73.98                                       Chez Felicia
# 514  44.65  -63.58                                      Hotel Halifax
# 530  60.75 -137.51                                       Parkside Inn
# 538  52.98 -122.49                             Ramada Limited Quesnel
# 557  53.92 -122.75               Canadas Best Value Inn Prince George

# %%
four_cities_df = pref_cities_df.loc[[463, 493, 511,557],:]
four_cities_df
# Out:
#      City_ID            City Country  Max Temp Current Description    Lat  \
# 463      463       flin flon      CA     10.17       broken clouds  54.77
# 493      493       hay river      CA     14.00          few clouds  60.82
# 511      511  saint-augustin      CA     30.99          light snow  45.63
# 557      557   prince george      CA     35.01          light rain  53.92
#
#         Lng                            Hotel Name
# 463 -101.88                Victoria Inn Flin Flon
# 493 -115.79                  Ptarmigan Inn Hotels
# 511  -73.98                          Chez Felicia
# 557 -122.75  Canadas Best Value Inn Prince George

# %%
coords = list(zip(four_cities_df["Lat"], four_cities_df["Lng"]))
coords
# Out:
# [(54.77, -101.88), (60.82, -115.79), (45.63, -73.98), (53.92, -122.75)]

# %%
# 7. Create a direction layer map using the start and end latitude-longitude pairs,
# and stop1, stop2, and stop3 as the waypoints. The travel_mode should be "DRIVING", "BICYCLING", or "WALKING".
# 7. Create a direction layer map using the start and end latitude-longitude pairs,
# and stop1, stop2, and stop3 as the waypoints. The travel_mode should be "DRIVING", "BICYCLING", or "WALKING".
fig = gmaps.figure() 
route = gmaps.directions_layer(coords[0], coords[-1], waypoints = [coords[1], coords[2], coords[3]], travel_mode ="DRIVING" )
fig.add_layer(route)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# 2. Using the template add the city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Weather</dt><dd>{Current Description} and {Max Temp}°F</dd>
</dl>
"""

# 3a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in four_cities_df.iterrows()]

# 3b. Get the latitude and longitude from each row and store in a new DataFrame.
locations =four_cities_df[["Lat", "Lng"]]

fig = gmaps.figure() 
marker_layer = gmaps.marker_layer(locations, info_box_content = hotel_info)
fig.add_layer(marker_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# 4a. Add a marker layer for each city to the map.
# 4a. Add a marker layer for each city to the map.
fig = gmaps.figure() 
marker_layer = gmaps.marker_layer(locations, info_box_content = hotel_info)
fig.add_layer(marker_layer)

fig
# 4b. Display the figure
# 4b. Display the figure
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-10-b4bb548299f3> in <module>
#       2 # 4a. Add a marker layer for each city to the map.
#       3 fig = gmaps.figure()
# ----> 4 marker_layer = gmaps.marker_layer(locations, info_box_content = hotel_info)
#       5 fig.add_layer(marker_layer)
#       6
#
# ~\anaconda3\envs\PythonData\lib\site-packages\gmaps\marker.py in marker_layer(locations, hover_text, label, info_box_content, display_info_box)
#     552     """
#     553     marker_options = _marker_layer_options(
# --> 554         locations, hover_text, label, info_box_content, display_info_box)
#     555     markers = [Marker(**option) for option in marker_options]
#     556     return Markers(markers=markers)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\gmaps\marker.py in _marker_layer_options(locations, hover_text, label, info_box_content, display_info_box)
#     323     marker_options.update(info_box_options)
#     324
# --> 325     return merge_option_dicts(marker_options)
#     326
#     327
#
# ~\anaconda3\envs\PythonData\lib\site-packages\gmaps\options.py in merge_option_dicts(option_dicts)
#      19     assert all(
#      20         length == number_items
# ---> 21         for length in option_values_lengths
#      22     )
#      23     option_lists = []
#
# AssertionError:

# %%
# 9 Using the template add city name, the country code, the weather description and maximum temperature for the city. 
info_box_template = """

"""

# 10a Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in itinerary_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = itinerary_df[["Lat", "Lng"]]

# %%
locations =pref_cities_df[["Lat", "Lng"]]
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Weather</dt><dd>{Current Description} and {Max Temp}°F</dd>
</dl>
"""

# 3a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in pref_cities_df.iterrows()]

fig = gmaps.figure()
marker_layer = gmaps.marker_layer(locations, info_box_content = hotel_info)
fig.add_layer(marker_layer)

fig

# %%
# 8. To create a marker layer map between the four cities.
#  Combine the four city DataFrames into one DataFrame using the concat() function.
itinerary_df = pd.concat([],ignore_index=True)
itinerary_df
