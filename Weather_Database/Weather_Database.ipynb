# %%
# dependecies 
import numpy as np 
import pandas as pd
from citipy import citipy
from datetime import datetime 
import requests

from config import weather_api_key

# %% [markdown]
# ### 1) Create a new set of 2,000 random latitudes & longitudes

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %% [markdown]
# ### 2) Get the nearest city using the citipy module

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 761

# %% [markdown]
# ### 3) Perform an API call with the OpenWeatherMap

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=492532aee06bc76badf06766a9613397

# %% [markdown]
# ### 4) Retrieve information from API call

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1


    # Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Description":city_description})
        
    

# If an error is experienced, skip the city.
    except Exception as e:
        print(e)
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | cortez
# Processing Record 2 of Set 1 | pevek
# Processing Record 3 of Set 1 | hermanus
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | atuona
# Processing Record 6 of Set 1 | hilo
# Processing Record 7 of Set 1 | khatanga
# Processing Record 8 of Set 1 | amderma
# 'sys'
# City not found. Skipping...
# Processing Record 9 of Set 1 | cape town
# Processing Record 10 of Set 1 | port alfred
# Processing Record 11 of Set 1 | denpasar
# Processing Record 12 of Set 1 | koplik
# Processing Record 13 of Set 1 | mar del plata
# Processing Record 14 of Set 1 | gogrial
# Processing Record 15 of Set 1 | flinders
# Processing Record 16 of Set 1 | guangyuan
# Processing Record 17 of Set 1 | punta arenas
# Processing Record 18 of Set 1 | rikitea
# Processing Record 19 of Set 1 | qaanaaq
# Processing Record 20 of Set 1 | mataura
# Processing Record 21 of Set 1 | bethel
# Processing Record 22 of Set 1 | mount isa
# Processing Record 23 of Set 1 | dikson
# Processing Record 24 of Set 1 | albany
# Processing Record 25 of Set 1 | yellowknife
# Processing Record 26 of Set 1 | tura
# Processing Record 27 of Set 1 | east london
# Processing Record 28 of Set 1 | castro
# Processing Record 29 of Set 1 | esperance
# Processing Record 30 of Set 1 | mahebourg
# Processing Record 31 of Set 1 | hithadhoo
# Processing Record 32 of Set 1 | vaini
# Processing Record 33 of Set 1 | ulenurme
# Processing Record 34 of Set 1 | busselton
# Processing Record 35 of Set 1 | oranjemund
# Processing Record 36 of Set 1 | bredasdorp
# Processing Record 37 of Set 1 | kaeo
# Processing Record 38 of Set 1 | bengkulu
# Processing Record 39 of Set 1 | nikolskoye
# Processing Record 40 of Set 1 | ilebo
# Processing Record 41 of Set 1 | zhengjiatun
# Processing Record 42 of Set 1 | souillac
# Processing Record 43 of Set 1 | bengkalis
# 'sys'
# City not found. Skipping...
# Processing Record 44 of Set 1 | havre-saint-pierre
# Processing Record 45 of Set 1 | arraial do cabo
# Processing Record 46 of Set 1 | mahaicony
# 'sys'
# City not found. Skipping...
# Processing Record 47 of Set 1 | airai
# Processing Record 48 of Set 1 | illoqqortoormiut
# 'sys'
# City not found. Skipping...
# Processing Record 49 of Set 1 | westport
# Processing Record 50 of Set 1 | port elizabeth
# Processing Record 1 of Set 2 | burhanpur
# Processing Record 2 of Set 2 | georgetown
# Processing Record 3 of Set 2 | daru
# Processing Record 4 of Set 2 | taolanaro
# 'sys'
# City not found. Skipping...
# Processing Record 5 of Set 2 | imbituba
# Processing Record 6 of Set 2 | agirish
# Processing Record 7 of Set 2 | montrose
# Processing Record 8 of Set 2 | ponta do sol
# Processing Record 9 of Set 2 | san cristobal
# Processing Record 10 of Set 2 | aripuana
# Processing Record 11 of Set 2 | barrow
# Processing Record 12 of Set 2 | deputatskiy
# Processing Record 13 of Set 2 | lebu
# Processing Record 14 of Set 2 | tuktoyaktuk
# Processing Record 15 of Set 2 | beringovskiy
# Processing Record 16 of Set 2 | alta floresta
# Processing Record 17 of Set 2 | provideniya
# Processing Record 18 of Set 2 | san rafael
# Processing Record 19 of Set 2 | pozhva
# Processing Record 20 of Set 2 | armidale
# Processing Record 21 of Set 2 | port blair
# Processing Record 22 of Set 2 | saint anthony
# Processing Record 23 of Set 2 | hobart
# Processing Record 24 of Set 2 | luderitz
# Processing Record 25 of Set 2 | puerto ayora
# Processing Record 26 of Set 2 | evensk
# Processing Record 27 of Set 2 | ruatoria
# 'sys'
# City not found. Skipping...
# Processing Record 28 of Set 2 | kudat
# Processing Record 29 of Set 2 | saint-philippe
# Processing Record 30 of Set 2 | seydi
# Processing Record 31 of Set 2 | cabo san lucas
# Processing Record 32 of Set 2 | balikpapan
# Processing Record 33 of Set 2 | marcona
# 'sys'
# City not found. Skipping...
# Processing Record 34 of Set 2 | sentyabrskiy
# 'sys'
# City not found. Skipping...
# Processing Record 35 of Set 2 | jamestown
# Processing Record 36 of Set 2 | chuy
# Processing Record 37 of Set 2 | jertih
# Processing Record 38 of Set 2 | norman wells
# Processing Record 39 of Set 2 | ambodifototra
# 'sys'
# City not found. Skipping...
# Processing Record 40 of Set 2 | college
# Processing Record 41 of Set 2 | klaksvik
# Processing Record 42 of Set 2 | hami
# Processing Record 43 of Set 2 | kruisfontein
# Processing Record 44 of Set 2 | thompson
# Processing Record 45 of Set 2 | fortuna
# Processing Record 46 of Set 2 | bluff
# Processing Record 47 of Set 2 | butaritari
# Processing Record 48 of Set 2 | neyshabur
# Processing Record 49 of Set 2 | haldwani
# Processing Record 50 of Set 2 | jacareacanga
# Processing Record 1 of Set 3 | cardston
# Processing Record 2 of Set 3 | jumla
# Processing Record 3 of Set 3 | gombong
# Processing Record 4 of Set 3 | ilo
# Processing Record 5 of Set 3 | nanortalik
# Processing Record 6 of Set 3 | ribeira grande
# Processing Record 7 of Set 3 | srandakan
# Processing Record 8 of Set 3 | srednekolymsk
# Processing Record 9 of Set 3 | kenora
# Processing Record 10 of Set 3 | chokurdakh
# Processing Record 11 of Set 3 | port hedland
# Processing Record 12 of Set 3 | mangrol
# Processing Record 13 of Set 3 | balkanabat
# Processing Record 14 of Set 3 | miles city
# Processing Record 15 of Set 3 | saint george
# Processing Record 16 of Set 3 | cherskiy
# Processing Record 17 of Set 3 | nizhneyansk
# 'sys'
# City not found. Skipping...
# Processing Record 18 of Set 3 | mys shmidta
# 'sys'
# City not found. Skipping...
# Processing Record 19 of Set 3 | faya
# Processing Record 20 of Set 3 | tezu
# Processing Record 21 of Set 3 | vyatskiye polyany
# Processing Record 22 of Set 3 | tombouctou
# Processing Record 23 of Set 3 | maragogi
# Processing Record 24 of Set 3 | lompoc
# Processing Record 25 of Set 3 | mandera
# Processing Record 26 of Set 3 | sawtell
# Processing Record 27 of Set 3 | rio grande
# Processing Record 28 of Set 3 | sur
# Processing Record 29 of Set 3 | kharan
# Processing Record 30 of Set 3 | basar
# Processing Record 31 of Set 3 | qasigiannguit
# Processing Record 32 of Set 3 | khor
# Processing Record 33 of Set 3 | tiznit
# Processing Record 34 of Set 3 | nouadhibou
# Processing Record 35 of Set 3 | kapaa
# Processing Record 36 of Set 3 | zhangye
# Processing Record 37 of Set 3 | gambo
# Processing Record 38 of Set 3 | selikhino
# Processing Record 39 of Set 3 | aviles
# Processing Record 40 of Set 3 | tasiilaq
# Processing Record 41 of Set 3 | kupang
# Processing Record 42 of Set 3 | egvekinot
# Processing Record 43 of Set 3 | hong gai
# Processing Record 44 of Set 3 | amapa
# Processing Record 45 of Set 3 | itarema
# Processing Record 46 of Set 3 | yershov
# Processing Record 47 of Set 3 | meulaboh
# Processing Record 48 of Set 3 | ingham
# Processing Record 49 of Set 3 | ongandjera
# Processing Record 50 of Set 3 | waddan
# Processing Record 1 of Set 4 | krasnoselkup
# Processing Record 2 of Set 4 | pacific grove
# Processing Record 3 of Set 4 | ishigaki
# Processing Record 4 of Set 4 | oktyabrskoye
# Processing Record 5 of Set 4 | suluq
# Processing Record 6 of Set 4 | praia da vitoria
# Processing Record 7 of Set 4 | attawapiskat
# 'sys'
# City not found. Skipping...
# Processing Record 8 of Set 4 | monywa
# Processing Record 9 of Set 4 | saleaula
# 'sys'
# City not found. Skipping...
# Processing Record 10 of Set 4 | eureka
# Processing Record 11 of Set 4 | vao
# Processing Record 12 of Set 4 | priyutnoye
# Processing Record 13 of Set 4 | riyadh
# Processing Record 14 of Set 4 | carnarvon
# Processing Record 15 of Set 4 | biak
# Processing Record 16 of Set 4 | komatipoort
# Processing Record 17 of Set 4 | santiago de cao
# Processing Record 18 of Set 4 | adrar
# Processing Record 19 of Set 4 | ancud
# Processing Record 20 of Set 4 | vila franca do campo
# Processing Record 21 of Set 4 | majene
# Processing Record 22 of Set 4 | rio gallegos
# Processing Record 23 of Set 4 | roma
# Processing Record 24 of Set 4 | severo-kurilsk
# Processing Record 25 of Set 4 | sorland
# Processing Record 26 of Set 4 | soyo
# Processing Record 27 of Set 4 | ontario
# Processing Record 28 of Set 4 | port lincoln
# Processing Record 29 of Set 4 | grindavik
# Processing Record 30 of Set 4 | tiksi
# Processing Record 31 of Set 4 | nanzhang
# Processing Record 32 of Set 4 | qaqortoq
# Processing Record 33 of Set 4 | chernyshevskiy
# Processing Record 34 of Set 4 | bargal
# 'sys'
# City not found. Skipping...
# Processing Record 35 of Set 4 | pimentel
# Processing Record 36 of Set 4 | vestmannaeyjar
# Processing Record 37 of Set 4 | aklavik
# Processing Record 38 of Set 4 | kavaratti
# Processing Record 39 of Set 4 | muisne
# Processing Record 40 of Set 4 | padang
# Processing Record 41 of Set 4 | chapais
# Processing Record 42 of Set 4 | kahului
# Processing Record 43 of Set 4 | general roca
# Processing Record 44 of Set 4 | leningradskiy
# Processing Record 45 of Set 4 | gien
# Processing Record 46 of Set 4 | bonavista
# Processing Record 47 of Set 4 | buala
# Processing Record 48 of Set 4 | kodiak
# Processing Record 49 of Set 4 | igarape-miri
# 'sys'
# City not found. Skipping...
# Processing Record 50 of Set 4 | freeport
# Processing Record 1 of Set 5 | bethanien
# Processing Record 2 of Set 5 | atambua
# Processing Record 3 of Set 5 | solnechnyy
# Processing Record 4 of Set 5 | bereda
# Processing Record 5 of Set 5 | brekstad
# Processing Record 6 of Set 5 | saskylakh
# Processing Record 7 of Set 5 | kaitangata
# Processing Record 8 of Set 5 | arrifes
# Processing Record 9 of Set 5 | geraldton
# Processing Record 10 of Set 5 | torbay
# Processing Record 11 of Set 5 | bardiyah
# Processing Record 12 of Set 5 | cidreira
# Processing Record 13 of Set 5 | upernavik
# Processing Record 14 of Set 5 | avarua
# Processing Record 15 of Set 5 | sisimiut
# Processing Record 16 of Set 5 | teahupoo
# Processing Record 17 of Set 5 | dunedin
# Processing Record 18 of Set 5 | san jose
# Processing Record 19 of Set 5 | moba
# Processing Record 20 of Set 5 | inhambane
# Processing Record 21 of Set 5 | hambantota
# Processing Record 22 of Set 5 | male
# Processing Record 23 of Set 5 | bogandinskiy
# Processing Record 24 of Set 5 | kutum
# Processing Record 25 of Set 5 | vallenar
# Processing Record 26 of Set 5 | belushya guba
# 'sys'
# City not found. Skipping...
# Processing Record 27 of Set 5 | khandagayty
# Processing Record 28 of Set 5 | bonthe
# Processing Record 29 of Set 5 | mirandopolis
# Processing Record 30 of Set 5 | mawlaik
# Processing Record 31 of Set 5 | shingu
# Processing Record 32 of Set 5 | gwadar
# Processing Record 33 of Set 5 | rivera
# Processing Record 34 of Set 5 | kathmandu
# Processing Record 35 of Set 5 | gistrup
# Processing Record 36 of Set 5 | ahumada
# 'sys'
# City not found. Skipping...
# Processing Record 37 of Set 5 | salym
# Processing Record 38 of Set 5 | juifang
# 'sys'
# City not found. Skipping...
# Processing Record 39 of Set 5 | ulaanbaatar
# Processing Record 40 of Set 5 | palabuhanratu
# 'sys'
# City not found. Skipping...
# Processing Record 41 of Set 5 | baykit
# Processing Record 42 of Set 5 | ormara
# Processing Record 43 of Set 5 | daokou
# Processing Record 44 of Set 5 | kharitonovo
# Processing Record 45 of Set 5 | bathsheba
# Processing Record 46 of Set 5 | vaasa
# Processing Record 47 of Set 5 | ostersund
# Processing Record 48 of Set 5 | vila
# Processing Record 49 of Set 5 | basudebpur
# Processing Record 50 of Set 5 | ostrovnoy
# Processing Record 1 of Set 6 | salinopolis
# Processing Record 2 of Set 6 | cap malheureux
# Processing Record 3 of Set 6 | macaboboni
# 'sys'
# City not found. Skipping...
# Processing Record 4 of Set 6 | new norfolk
# Processing Record 5 of Set 6 | luanda
# Processing Record 6 of Set 6 | soe
# Processing Record 7 of Set 6 | fereydun kenar
# Processing Record 8 of Set 6 | hunza
# 'sys'
# City not found. Skipping...
# Processing Record 9 of Set 6 | kabalo
# Processing Record 10 of Set 6 | vaitupu
# 'sys'
# City not found. Skipping...
# Processing Record 11 of Set 6 | salalah
# Processing Record 12 of Set 6 | barentsburg
# 'sys'
# City not found. Skipping...
# Processing Record 13 of Set 6 | gerede
# Processing Record 14 of Set 6 | hasaki
# Processing Record 15 of Set 6 | alexander city
# Processing Record 16 of Set 6 | phan thiet
# Processing Record 17 of Set 6 | tautira
# Processing Record 18 of Set 6 | mizan teferi
# Processing Record 19 of Set 6 | aksarka
# Processing Record 20 of Set 6 | hay river
# Processing Record 21 of Set 6 | san patricio
# Processing Record 22 of Set 6 | san ramon
# Processing Record 23 of Set 6 | almaznyy
# Processing Record 24 of Set 6 | uusikaupunki
# Processing Record 25 of Set 6 | zwedru
# Processing Record 26 of Set 6 | taldan
# Processing Record 27 of Set 6 | nome
# Processing Record 28 of Set 6 | grenaa
# Processing Record 29 of Set 6 | richards bay
# Processing Record 30 of Set 6 | nakusp
# Processing Record 31 of Set 6 | narsaq
# Processing Record 32 of Set 6 | klyuchi
# Processing Record 33 of Set 6 | iskateley
# Processing Record 34 of Set 6 | faanui
# Processing Record 35 of Set 6 | zhanaozen
# Processing Record 36 of Set 6 | puerto baquerizo moreno
# Processing Record 37 of Set 6 | aykhal
# Processing Record 38 of Set 6 | berbera
# Processing Record 39 of Set 6 | dzhusaly
# 'sys'
# City not found. Skipping...
# Processing Record 40 of Set 6 | roald
# Processing Record 41 of Set 6 | komsomolskiy
# Processing Record 42 of Set 6 | xinzhou
# Processing Record 43 of Set 6 | abeche
# Processing Record 44 of Set 6 | dingle
# Processing Record 45 of Set 6 | sibut
# Processing Record 46 of Set 6 | barcelona
# Processing Record 47 of Set 6 | bambous virieux
# Processing Record 48 of Set 6 | samarai
# Processing Record 49 of Set 6 | havelock
# Processing Record 50 of Set 6 | grand river south east
# 'sys'
# City not found. Skipping...
# Processing Record 1 of Set 7 | athabasca
# Processing Record 2 of Set 7 | alofi
# Processing Record 3 of Set 7 | viedma
# Processing Record 4 of Set 7 | fort payne
# Processing Record 5 of Set 7 | mikhaylovka
# Processing Record 6 of Set 7 | north bend
# Processing Record 7 of Set 7 | xining
# Processing Record 8 of Set 7 | pandan
# Processing Record 9 of Set 7 | talnakh
# Processing Record 10 of Set 7 | sibolga
# Processing Record 11 of Set 7 | codrington
# Processing Record 12 of Set 7 | ilulissat
# Processing Record 13 of Set 7 | oktyabrskiy
# Processing Record 14 of Set 7 | port hardy
# Processing Record 15 of Set 7 | nara
# Processing Record 16 of Set 7 | thinadhoo
# Processing Record 17 of Set 7 | vila velha
# Processing Record 18 of Set 7 | coihaique
# Processing Record 19 of Set 7 | buckeye
# Processing Record 20 of Set 7 | vardo
# Processing Record 21 of Set 7 | cockburn town
# Processing Record 22 of Set 7 | obo
# Processing Record 23 of Set 7 | bandar
# Processing Record 24 of Set 7 | sosnovo-ozerskoye
# Processing Record 25 of Set 7 | ponta delgada
# Processing Record 26 of Set 7 | grootfontein
# Processing Record 27 of Set 7 | saint-raphael
# Processing Record 28 of Set 7 | samusu
# 'sys'
# City not found. Skipping...
# Processing Record 29 of Set 7 | trat
# Processing Record 30 of Set 7 | rawannawi
# 'sys'
# City not found. Skipping...
# Processing Record 31 of Set 7 | lasa
# Processing Record 32 of Set 7 | half moon bay
# Processing Record 33 of Set 7 | burnie
# Processing Record 34 of Set 7 | basirhat
# Processing Record 35 of Set 7 | mariel
# Processing Record 36 of Set 7 | tidore
# 'sys'
# City not found. Skipping...
# Processing Record 37 of Set 7 | bow island
# Processing Record 38 of Set 7 | trencin
# Processing Record 39 of Set 7 | antofagasta
# Processing Record 40 of Set 7 | terrace
# Processing Record 41 of Set 7 | bubaque
# Processing Record 42 of Set 7 | conceicao do araguaia
# Processing Record 43 of Set 7 | guerrero negro
# Processing Record 44 of Set 7 | juarez
# Processing Record 45 of Set 7 | kanel
# Processing Record 46 of Set 7 | taoudenni
# Processing Record 47 of Set 7 | sangar
# Processing Record 48 of Set 7 | tarabuco
# Processing Record 49 of Set 7 | liliani
# Processing Record 50 of Set 7 | olinda
# Processing Record 1 of Set 8 | fairbanks
# Processing Record 2 of Set 8 | orje
# Processing Record 3 of Set 8 | xingyi
# Processing Record 4 of Set 8 | reyes
# Processing Record 5 of Set 8 | tunduru
# 'sys'
# City not found. Skipping...
# Processing Record 6 of Set 8 | carutapera
# Processing Record 7 of Set 8 | mocuba
# Processing Record 8 of Set 8 | peleduy
# Processing Record 9 of Set 8 | gizo
# Processing Record 10 of Set 8 | gbarnga
# Processing Record 11 of Set 8 | wajir
# Processing Record 12 of Set 8 | tsimlyansk
# Processing Record 13 of Set 8 | victoria
# Processing Record 14 of Set 8 | moorpark
# Processing Record 15 of Set 8 | udachnyy
# Processing Record 16 of Set 8 | rincon
# Processing Record 17 of Set 8 | alice springs
# Processing Record 18 of Set 8 | assiniboia
# Processing Record 19 of Set 8 | sijunjung
# Processing Record 20 of Set 8 | kadykchan
# 'sys'
# City not found. Skipping...
# Processing Record 21 of Set 8 | slyudyanka
# Processing Record 22 of Set 8 | yining
# Processing Record 23 of Set 8 | kibala
# Processing Record 24 of Set 8 | pisco
# Processing Record 25 of Set 8 | abalak
# Processing Record 26 of Set 8 | mao
# Processing Record 27 of Set 8 | karkaralinsk
# 'sys'
# City not found. Skipping...
# Processing Record 28 of Set 8 | luba
# Processing Record 29 of Set 8 | ayr
# Processing Record 30 of Set 8 | ninomiya
# Processing Record 31 of Set 8 | kununurra
# Processing Record 32 of Set 8 | oskemen
# Processing Record 33 of Set 8 | cayenne
# Processing Record 34 of Set 8 | shimanovsk
# Processing Record 35 of Set 8 | mackay
# Processing Record 36 of Set 8 | lamu
# Processing Record 37 of Set 8 | mwinilunga
# Processing Record 38 of Set 8 | sikonge
# Processing Record 39 of Set 8 | matara
# Processing Record 40 of Set 8 | sambava
# Processing Record 41 of Set 8 | dien bien
# 'sys'
# City not found. Skipping...
# Processing Record 42 of Set 8 | dubti
# Processing Record 43 of Set 8 | tsihombe
# 'sys'
# City not found. Skipping...
# Processing Record 44 of Set 8 | husavik
# Processing Record 45 of Set 8 | henties bay
# Processing Record 46 of Set 8 | usinsk
# Processing Record 47 of Set 8 | ambon
# Processing Record 48 of Set 8 | katsuura
# Processing Record 49 of Set 8 | vibo valentia
# Processing Record 50 of Set 8 | orlik
# Processing Record 1 of Set 9 | petushki
# Processing Record 2 of Set 9 | longyearbyen
# Processing Record 3 of Set 9 | rocha
# Processing Record 4 of Set 9 | melfi
# Processing Record 5 of Set 9 | aragats
# Processing Record 6 of Set 9 | dhoraji
# Processing Record 7 of Set 9 | tizimin
# Processing Record 8 of Set 9 | poso
# Processing Record 9 of Set 9 | sal rei
# Processing Record 10 of Set 9 | toora-khem
# Processing Record 11 of Set 9 | sao joao da barra
# Processing Record 12 of Set 9 | los llanos de aridane
# Processing Record 13 of Set 9 | manzanillo
# Processing Record 14 of Set 9 | mopipi
# Processing Record 15 of Set 9 | punta alta
# Processing Record 16 of Set 9 | tumannyy
# 'sys'
# City not found. Skipping...
# Processing Record 17 of Set 9 | hohhot
# Processing Record 18 of Set 9 | urumqi
# Processing Record 19 of Set 9 | limon
# Processing Record 20 of Set 9 | laguna
# Processing Record 21 of Set 9 | naze
# Processing Record 22 of Set 9 | zyryanka
# Processing Record 23 of Set 9 | grand gaube
# Processing Record 24 of Set 9 | surgut
# Processing Record 25 of Set 9 | brookhaven
# Processing Record 26 of Set 9 | outlook
# Processing Record 27 of Set 9 | vysokogornyy
# Processing Record 28 of Set 9 | merced
# Processing Record 29 of Set 9 | kiama
# Processing Record 30 of Set 9 | millington
# Processing Record 31 of Set 9 | traverse city
# Processing Record 32 of Set 9 | progreso
# Processing Record 33 of Set 9 | katima mulilo
# Processing Record 34 of Set 9 | mandali
# Processing Record 35 of Set 9 | kachug
# Processing Record 36 of Set 9 | sumbawa
# 'sys'
# City not found. Skipping...
# Processing Record 37 of Set 9 | rawson
# Processing Record 38 of Set 9 | invermere
# Processing Record 39 of Set 9 | gurskoye
# 'sys'
# City not found. Skipping...
# Processing Record 40 of Set 9 | kumluca
# Processing Record 41 of Set 9 | randolph
# Processing Record 42 of Set 9 | mutare
# Processing Record 43 of Set 9 | east wenatchee bench
# Processing Record 44 of Set 9 | hervey bay
# Processing Record 45 of Set 9 | lorengau
# Processing Record 46 of Set 9 | namibe
# Processing Record 47 of Set 9 | tocopilla
# Processing Record 48 of Set 9 | jimma
# Processing Record 49 of Set 9 | iqaluit
# Processing Record 50 of Set 9 | puerto escondido
# Processing Record 1 of Set 10 | skibbereen
# Processing Record 2 of Set 10 | mayskiy
# Processing Record 3 of Set 10 | havoysund
# Processing Record 4 of Set 10 | price
# Processing Record 5 of Set 10 | sola
# Processing Record 6 of Set 10 | rungata
# 'sys'
# City not found. Skipping...
# Processing Record 7 of Set 10 | neiafu
# Processing Record 8 of Set 10 | san andres
# Processing Record 9 of Set 10 | sivas
# Processing Record 10 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 11 of Set 10 | vostok
# Processing Record 12 of Set 10 | tarragona
# Processing Record 13 of Set 10 | touros
# Processing Record 14 of Set 10 | san pedro
# Processing Record 15 of Set 10 | grand baie
# Processing Record 16 of Set 10 | launceston
# Processing Record 17 of Set 10 | xinmin
# Processing Record 18 of Set 10 | cangzhou
# Processing Record 19 of Set 10 | lazaro cardenas
# Processing Record 20 of Set 10 | hazorasp
# Processing Record 21 of Set 10 | kloulklubed
# Processing Record 22 of Set 10 | annino
# Processing Record 23 of Set 10 | tessalit
# Processing Record 24 of Set 10 | sargatskoye
# Processing Record 25 of Set 10 | porirua
# Processing Record 26 of Set 10 | uhlove
# Processing Record 27 of Set 10 | bakel
# Processing Record 28 of Set 10 | northam
# Processing Record 29 of Set 10 | pljevlja
# Processing Record 30 of Set 10 | grand-lahou
# Processing Record 31 of Set 10 | mergui
# 'sys'
# City not found. Skipping...
# Processing Record 32 of Set 10 | goksun
# Processing Record 33 of Set 10 | marquette
# Processing Record 34 of Set 10 | saldanha
# Processing Record 35 of Set 10 | galeana
# Processing Record 36 of Set 10 | umm lajj
# Processing Record 37 of Set 10 | buariki
# 'sys'
# City not found. Skipping...
# Processing Record 38 of Set 10 | kolaras
# Processing Record 39 of Set 10 | huilong
# Processing Record 40 of Set 10 | aviemore
# Processing Record 41 of Set 10 | kholtoson
# Processing Record 42 of Set 10 | ndjole
# Processing Record 43 of Set 10 | sinnamary
# Processing Record 44 of Set 10 | angoram
# Processing Record 45 of Set 10 | hualmay
# Processing Record 46 of Set 10 | nyimba
# Processing Record 47 of Set 10 | lynn haven
# Processing Record 48 of Set 10 | kirakira
# Processing Record 49 of Set 10 | hovd
# Processing Record 50 of Set 10 | labuhan
# Processing Record 1 of Set 11 | pangnirtung
# Processing Record 2 of Set 11 | damietta
# Processing Record 3 of Set 11 | arvin
# Processing Record 4 of Set 11 | sao filipe
# Processing Record 5 of Set 11 | sitka
# Processing Record 6 of Set 11 | orange
# Processing Record 7 of Set 11 | broome
# Processing Record 8 of Set 11 | concarneau
# Processing Record 9 of Set 11 | lavrentiya
# Processing Record 10 of Set 11 | kamenskoye
# 'sys'
# City not found. Skipping...
# Processing Record 11 of Set 11 | ranong
# Processing Record 12 of Set 11 | auki
# Processing Record 13 of Set 11 | necochea
# Processing Record 14 of Set 11 | broken hill
# Processing Record 15 of Set 11 | svetlaya
# Processing Record 16 of Set 11 | avera
# Processing Record 17 of Set 11 | oxapampa
# Processing Record 18 of Set 11 | del rio
# Processing Record 19 of Set 11 | posevnaya
# Processing Record 20 of Set 11 | alcains
# Processing Record 21 of Set 11 | honningsvag
# Processing Record 22 of Set 11 | isangel
# Processing Record 23 of Set 11 | carauari
# Processing Record 24 of Set 11 | aguachica
# Processing Record 25 of Set 11 | jalu
# Processing Record 26 of Set 11 | baoding
# Processing Record 27 of Set 11 | xam nua
# Processing Record 28 of Set 11 | tokur
# Processing Record 29 of Set 11 | nemuro
# Processing Record 30 of Set 11 | benghazi
# Processing Record 31 of Set 11 | ixtapa
# Processing Record 32 of Set 11 | macomer
# Processing Record 33 of Set 11 | marilandia
# Processing Record 34 of Set 11 | sungaipenuh
# Processing Record 35 of Set 11 | jawhar
# Processing Record 36 of Set 11 | olga
# Processing Record 37 of Set 11 | cockburn harbour
# 'sys'
# City not found. Skipping...
# Processing Record 38 of Set 11 | whitefish
# Processing Record 39 of Set 11 | boyuibe
# Processing Record 40 of Set 11 | lamar
# Processing Record 41 of Set 11 | mahajanga
# Processing Record 42 of Set 11 | viseu
# Processing Record 43 of Set 11 | miramar
# Processing Record 44 of Set 11 | axim
# Processing Record 45 of Set 11 | kamaishi
# Processing Record 46 of Set 11 | saint-francois
# Processing Record 47 of Set 11 | djenne
# Processing Record 48 of Set 11 | batemans bay
# Processing Record 49 of Set 11 | poum
# Processing Record 50 of Set 11 | kavieng
# Processing Record 1 of Set 12 | kamloops
# Processing Record 2 of Set 12 | harper
# Processing Record 3 of Set 12 | poya
# Processing Record 4 of Set 12 | burica
# 'sys'
# City not found. Skipping...
# Processing Record 5 of Set 12 | villazon
# Processing Record 6 of Set 12 | korcula
# Processing Record 7 of Set 12 | dehui
# Processing Record 8 of Set 12 | tamworth
# Processing Record 9 of Set 12 | karauzyak
# 'sys'
# City not found. Skipping...
# Processing Record 10 of Set 12 | muros
# Processing Record 11 of Set 12 | vagur
# Processing Record 12 of Set 12 | mubi
# Processing Record 13 of Set 12 | hebi
# Processing Record 14 of Set 12 | kimbe
# Processing Record 15 of Set 12 | awjilah
# Processing Record 16 of Set 12 | domoni
# Processing Record 17 of Set 12 | seoul
# Processing Record 18 of Set 12 | mbarara
# Processing Record 19 of Set 12 | abingdon
# Processing Record 20 of Set 12 | cristalina
# Processing Record 21 of Set 12 | banmo
# 'sys'
# City not found. Skipping...
# Processing Record 22 of Set 12 | kudahuvadhoo
# Processing Record 23 of Set 12 | lucapa
# Processing Record 24 of Set 12 | yavas
# Processing Record 25 of Set 12 | vredendal
# Processing Record 26 of Set 12 | beibei
# Processing Record 27 of Set 12 | yerbogachen
# Processing Record 28 of Set 12 | diphu
# Processing Record 29 of Set 12 | yulara
# Processing Record 30 of Set 12 | merauke
# Processing Record 31 of Set 12 | korla
# Processing Record 32 of Set 12 | pundaguitan
# Processing Record 33 of Set 12 | we
# 'sys'
# City not found. Skipping...
# Processing Record 34 of Set 12 | lagoa
# Processing Record 35 of Set 12 | adwa
# Processing Record 36 of Set 12 | marawi
# Processing Record 37 of Set 12 | serenje
# Processing Record 38 of Set 12 | champerico
# Processing Record 39 of Set 12 | ekhabi
# Processing Record 40 of Set 12 | kuche
# 'sys'
# City not found. Skipping...
# Processing Record 41 of Set 12 | bud
# Processing Record 42 of Set 12 | nago
# Processing Record 43 of Set 12 | darhan
# Processing Record 44 of Set 12 | arcata
# Processing Record 45 of Set 12 | verkhoyansk
# Processing Record 46 of Set 12 | livramento
# Processing Record 47 of Set 12 | great bend
# Processing Record 48 of Set 12 | ola
# Processing Record 49 of Set 12 | pitogo
# Processing Record 50 of Set 12 | matamoros
# Processing Record 1 of Set 13 | boralday
# Processing Record 2 of Set 13 | bor
# Processing Record 3 of Set 13 | luena
# Processing Record 4 of Set 13 | san vicente
# Processing Record 5 of Set 13 | bronnoysund
# Processing Record 6 of Set 13 | norilsk
# Processing Record 7 of Set 13 | mae chan
# Processing Record 8 of Set 13 | lumberton
# Processing Record 9 of Set 13 | pinerolo
# Processing Record 10 of Set 13 | swan hill
# Processing Record 11 of Set 13 | calvinia
# Processing Record 12 of Set 13 | mana
# Processing Record 13 of Set 13 | nalchiti
# Processing Record 14 of Set 13 | taitung
# Processing Record 15 of Set 13 | nsanje
# Processing Record 16 of Set 13 | malia
# Processing Record 17 of Set 13 | guanica
# Processing Record 18 of Set 13 | kazalinsk
# 'sys'
# City not found. Skipping...
# Processing Record 19 of Set 13 | paamiut
# Processing Record 20 of Set 13 | tamiahua
# Processing Record 21 of Set 13 | tevaitoa
# Processing Record 22 of Set 13 | segou
# Processing Record 23 of Set 13 | strezhevoy
# Processing Record 24 of Set 13 | ahipara
# Processing Record 25 of Set 13 | coquimbo
# Processing Record 26 of Set 13 | semey
# Processing Record 27 of Set 13 | hofn
# Processing Record 28 of Set 13 | honiara
# Processing Record 29 of Set 13 | rosario
# Processing Record 30 of Set 13 | morros
# Processing Record 31 of Set 13 | mount gambier
# Processing Record 32 of Set 13 | ketchikan
# Processing Record 33 of Set 13 | puerto el triunfo
# Processing Record 34 of Set 13 | umzimvubu
# 'sys'
# City not found. Skipping...
# Processing Record 35 of Set 13 | iralaya
# Processing Record 36 of Set 13 | cochrane
# Processing Record 37 of Set 13 | tiruchchendur
# Processing Record 38 of Set 13 | dunda
# Processing Record 39 of Set 13 | butiama
# Processing Record 40 of Set 13 | cotui
# Processing Record 41 of Set 13 | terney
# Processing Record 42 of Set 13 | dharchula
# Processing Record 43 of Set 13 | ambilobe
# Processing Record 44 of Set 13 | eyl
# Processing Record 45 of Set 13 | bolshegrivskoye
# 'sys'
# City not found. Skipping...
# Processing Record 46 of Set 13 | deh rawud
# 'sys'
# City not found. Skipping...
# Processing Record 47 of Set 13 | tymovskoye
# Processing Record 48 of Set 13 | horn lake
# Processing Record 49 of Set 13 | nuevo ideal
# Processing Record 50 of Set 13 | port shepstone
# Processing Record 1 of Set 14 | catalina foothills
# Processing Record 2 of Set 14 | moose factory
# Processing Record 3 of Set 14 | labytnangi
# Processing Record 4 of Set 14 | yar-sale
# Processing Record 5 of Set 14 | itoman
# Processing Record 6 of Set 14 | beipiao
# Processing Record 7 of Set 14 | ledyard
# Processing Record 8 of Set 14 | aksu
# Processing Record 9 of Set 14 | goundam
# Processing Record 10 of Set 14 | mogadouro
# Processing Record 11 of Set 14 | maniitsoq
# Processing Record 12 of Set 14 | aguimes
# Processing Record 13 of Set 14 | coahuayana
# Processing Record 14 of Set 14 | seymchan
# Processing Record 15 of Set 14 | plouzane
# Processing Record 16 of Set 14 | santiago de cuba
# Processing Record 17 of Set 14 | dryden
# Processing Record 18 of Set 14 | skelleftea
# Processing Record 19 of Set 14 | mlalo
# Processing Record 20 of Set 14 | christchurch
# Processing Record 21 of Set 14 | homer
# Processing Record 22 of Set 14 | waseca
# Processing Record 23 of Set 14 | teguise
# Processing Record 24 of Set 14 | khandyga
# Processing Record 25 of Set 14 | kayalpattinam
# Processing Record 26 of Set 14 | noyabrsk
# Processing Record 27 of Set 14 | raton
# Processing Record 28 of Set 14 | yuyao
# Processing Record 29 of Set 14 | manhattan
# Processing Record 30 of Set 14 | ust-ishim
# Processing Record 31 of Set 14 | maromitsa
# Processing Record 32 of Set 14 | mumford
# Processing Record 33 of Set 14 | jubb jannin
# 'sys'
# City not found. Skipping...
# Processing Record 34 of Set 14 | baherden
# Processing Record 35 of Set 14 | liverpool
# Processing Record 36 of Set 14 | mansa
# Processing Record 37 of Set 14 | saurimo
# Processing Record 38 of Set 14 | nurota
# Processing Record 39 of Set 14 | tamandare
# Processing Record 40 of Set 14 | chumikan
# Processing Record 41 of Set 14 | mareeba
# Processing Record 42 of Set 14 | algeciras
# Processing Record 43 of Set 14 | raudeberg
# Processing Record 44 of Set 14 | dahuk
# Processing Record 45 of Set 14 | crib point
# Processing Record 46 of Set 14 | otane
# Processing Record 47 of Set 14 | bambanglipuro
# Processing Record 48 of Set 14 | tecoanapa
# Processing Record 49 of Set 14 | belen
# Processing Record 50 of Set 14 | narok
# Processing Record 1 of Set 15 | cuamba
# Processing Record 2 of Set 15 | vuktyl
# Processing Record 3 of Set 15 | kulhudhuffushi
# Processing Record 4 of Set 15 | constantine
# Processing Record 5 of Set 15 | umm kaddadah
# Processing Record 6 of Set 15 | vulcan
# Processing Record 7 of Set 15 | oussouye
# Processing Record 8 of Set 15 | marataizes
# Processing Record 9 of Set 15 | stornoway
# Processing Record 10 of Set 15 | palembang
# Processing Record 11 of Set 15 | vilyuysk
# Processing Record 12 of Set 15 | arya
# Processing Record 13 of Set 15 | caravelas
# Processing Record 14 of Set 15 | porto de moz
# Processing Record 15 of Set 15 | cumberland
# Processing Record 16 of Set 15 | mnogovershinnyy
# Processing Record 17 of Set 15 | horsham
# Processing Record 18 of Set 15 | mehamn
# Processing Record 19 of Set 15 | aichach
# Processing Record 20 of Set 15 | dubrovnik
# Processing Record 21 of Set 15 | ulagan
# Processing Record 22 of Set 15 | mantua
# Processing Record 23 of Set 15 | lubango
# Processing Record 24 of Set 15 | ahtopol
# Processing Record 25 of Set 15 | kailua
# Processing Record 26 of Set 15 | san felipe
# Processing Record 27 of Set 15 | gunjur
# Processing Record 28 of Set 15 | clyde river
# Processing Record 29 of Set 15 | myitkyina
# Processing Record 30 of Set 15 | gosainganj
# Processing Record 31 of Set 15 | araguari
# Processing Record 32 of Set 15 | ilva mica
# Processing Record 33 of Set 15 | tomatlan
# Processing Record 34 of Set 15 | sao sebastiao
# Processing Record 35 of Set 15 | ngunguru
# Processing Record 36 of Set 15 | barreirinha
# Processing Record 37 of Set 15 | hailey
# Processing Record 38 of Set 15 | yangjiang
# Processing Record 39 of Set 15 | malpe
# Processing Record 40 of Set 15 | gladstone
# Processing Record 41 of Set 15 | yeppoon
# Processing Record 42 of Set 15 | whitianga
# Processing Record 43 of Set 15 | damaturu
# Processing Record 44 of Set 15 | saint-augustin
# Processing Record 45 of Set 15 | kitimat
# Processing Record 46 of Set 15 | pontes e lacerda
# Processing Record 47 of Set 15 | dhidhdhoo
# Processing Record 48 of Set 15 | kishi
# Processing Record 49 of Set 15 | rostovka
# Processing Record 50 of Set 15 | esmeralda
# Processing Record 1 of Set 16 | sterling
# Processing Record 2 of Set 16 | yialos
# 'sys'
# City not found. Skipping...
# Processing Record 3 of Set 16 | portree
# Processing Record 4 of Set 16 | mogadishu
# Processing Record 5 of Set 16 | zhigansk
# Processing Record 6 of Set 16 | carmen
# Processing Record 7 of Set 16 | bani
# Processing Record 8 of Set 16 | yumen
# Processing Record 9 of Set 16 | ugoofaaru
# Processing Record 10 of Set 16 | saraj
# Processing Record 11 of Set 16 | sangolqui
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### 5) Add data to new DataFrame

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       Cortez  37.35 -108.59     77.00        22           1        5.82
# 1        Pevek  69.70  170.31     45.68        69          27       14.58
# 2     Hermanus -34.42   19.23     52.23        84           4        7.61
# 3      Ushuaia -54.80  -68.30     35.60        89          40       10.29
# 4       Atuona  -9.80 -139.03     78.66        77          19       18.61
# 5         Hilo  19.73 -155.09     82.40        61          90        8.05
# 6     Khatanga  71.97  102.50     52.90        55           0        4.72
# 7    Cape Town -33.93   18.42     48.99        93           0        1.12
# 8  Port Alfred -33.59   26.89     58.01        86          26       10.16
# 9     Denpasar  -8.65  115.22     84.20        83          20       16.11
#
#   Country                 Date       Description
# 0      US  2020-09-07 03:51:58         clear sky
# 1      RU  2020-09-07 03:48:53  scattered clouds
# 2      ZA  2020-09-07 03:48:38         clear sky
# 3      AR  2020-09-07 03:48:36  scattered clouds
# 4      PF  2020-09-07 03:51:58        light rain
# 5      US  2020-09-07 03:51:59   overcast clouds
# 6      RU  2020-09-07 03:51:59         clear sky
# 7      ZA  2020-09-07 03:51:59         clear sky
# 8      ZA  2020-09-07 03:52:00  scattered clouds
# 9      ID  2020-09-07 03:49:25        few clouds

# %% [markdown]
# ### 6) export DataFrame as a CSV file & save it as WeatherPy_Database.csv in Weather_Database folder

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
