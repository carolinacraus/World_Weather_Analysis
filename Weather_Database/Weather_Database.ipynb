# %%
# dependecies 
import numpy as np 
import pandas as pd
from citipy import citipy
from datetime import datetime 
import requests

from config import weather_api_key

# %% [markdown]
# ### 1) Create a new set of 2,000 random latitudes & longitudes

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %% [markdown]
# ### 2) Get the nearest city using the citipy module

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 717

# %% [markdown]
# ### 3) Perform an API call with the OpenWeatherMap

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=492532aee06bc76badf06766a9613397

# %% [markdown]
# ### 4) Retrieve information from API call

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1


    # Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | conneaut
# Processing Record 3 of Set 1 | lagoa
# Processing Record 4 of Set 1 | albany
# Processing Record 5 of Set 1 | norman wells
# Processing Record 6 of Set 1 | farmersville
# Processing Record 7 of Set 1 | rikitea
# Processing Record 8 of Set 1 | hermanus
# Processing Record 9 of Set 1 | inhambane
# Processing Record 10 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 11 of Set 1 | saint-philippe
# Processing Record 12 of Set 1 | barrow
# Processing Record 13 of Set 1 | asau
# Processing Record 14 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 15 of Set 1 | bethel
# Processing Record 16 of Set 1 | bathsheba
# Processing Record 17 of Set 1 | sur
# Processing Record 18 of Set 1 | beringovskiy
# Processing Record 19 of Set 1 | mukhen
# Processing Record 20 of Set 1 | avarua
# Processing Record 21 of Set 1 | ponta do sol
# Processing Record 22 of Set 1 | cape town
# Processing Record 23 of Set 1 | lavrentiya
# Processing Record 24 of Set 1 | kamenskoye
# City not found. Skipping...
# Processing Record 25 of Set 1 | new norfolk
# Processing Record 26 of Set 1 | mar del plata
# Processing Record 27 of Set 1 | verkhoyansk
# Processing Record 28 of Set 1 | castro
# Processing Record 29 of Set 1 | arraial do cabo
# Processing Record 30 of Set 1 | port elizabeth
# Processing Record 31 of Set 1 | anadyr
# Processing Record 32 of Set 1 | victoria
# Processing Record 33 of Set 1 | ilulissat
# Processing Record 34 of Set 1 | mount gambier
# Processing Record 35 of Set 1 | butaritari
# Processing Record 36 of Set 1 | thompson
# Processing Record 37 of Set 1 | gorom-gorom
# Processing Record 38 of Set 1 | berestechko
# Processing Record 39 of Set 1 | vanavara
# Processing Record 40 of Set 1 | kaitangata
# Processing Record 41 of Set 1 | punta arenas
# Processing Record 42 of Set 1 | hobart
# Processing Record 43 of Set 1 | yellowknife
# Processing Record 44 of Set 1 | galgani
# City not found. Skipping...
# Processing Record 45 of Set 1 | alofi
# Processing Record 46 of Set 1 | bengkulu
# Processing Record 47 of Set 1 | margate
# Processing Record 48 of Set 1 | souillac
# Processing Record 49 of Set 1 | puerto ayora
# Processing Record 50 of Set 1 | dikson
# Processing Record 1 of Set 2 | pangani
# Processing Record 2 of Set 2 | sivaki
# Processing Record 3 of Set 2 | kapaa
# Processing Record 4 of Set 2 | hay river
# Processing Record 5 of Set 2 | mataura
# Processing Record 6 of Set 2 | burica
# City not found. Skipping...
# Processing Record 7 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 8 of Set 2 | bluff
# Processing Record 9 of Set 2 | bemidji
# Processing Record 10 of Set 2 | kerteh
# City not found. Skipping...
# Processing Record 11 of Set 2 | provideniya
# Processing Record 12 of Set 2 | pingliang
# Processing Record 13 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 14 of Set 2 | palana
# Processing Record 15 of Set 2 | geraldton
# Processing Record 16 of Set 2 | den helder
# Processing Record 17 of Set 2 | hithadhoo
# Processing Record 18 of Set 2 | longyearbyen
# Processing Record 19 of Set 2 | muros
# Processing Record 20 of Set 2 | te anau
# Processing Record 21 of Set 2 | port alfred
# Processing Record 22 of Set 2 | parral
# Processing Record 23 of Set 2 | tuktoyaktuk
# Processing Record 24 of Set 2 | meyungs
# City not found. Skipping...
# Processing Record 25 of Set 2 | katsuura
# Processing Record 26 of Set 2 | busselton
# Processing Record 27 of Set 2 | kermanshah
# Processing Record 28 of Set 2 | carnarvon
# Processing Record 29 of Set 2 | bonavista
# Processing Record 30 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 31 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 32 of Set 2 | rongcheng
# Processing Record 33 of Set 2 | qaanaaq
# Processing Record 34 of Set 2 | ballina
# Processing Record 35 of Set 2 | mount isa
# Processing Record 36 of Set 2 | fairbanks
# Processing Record 37 of Set 2 | leningradskiy
# Processing Record 38 of Set 2 | vaini
# Processing Record 39 of Set 2 | delijan
# Processing Record 40 of Set 2 | xiongyue
# Processing Record 41 of Set 2 | salamanca
# Processing Record 42 of Set 2 | tuatapere
# Processing Record 43 of Set 2 | port hardy
# Processing Record 44 of Set 2 | kyshtovka
# Processing Record 45 of Set 2 | bredasdorp
# Processing Record 46 of Set 2 | atuona
# Processing Record 47 of Set 2 | fengxian
# Processing Record 48 of Set 2 | ancud
# Processing Record 49 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 50 of Set 2 | chokurdakh
# Processing Record 1 of Set 3 | lompoc
# Processing Record 2 of Set 3 | beibei
# Processing Record 3 of Set 3 | caravelas
# Processing Record 4 of Set 3 | anloga
# Processing Record 5 of Set 3 | chuy
# Processing Record 6 of Set 3 | nikolskoye
# Processing Record 7 of Set 3 | ranong
# Processing Record 8 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 9 of Set 3 | isangel
# Processing Record 10 of Set 3 | toftir
# City not found. Skipping...
# Processing Record 11 of Set 3 | wanaka
# Processing Record 12 of Set 3 | oranjemund
# Processing Record 13 of Set 3 | olinda
# Processing Record 14 of Set 3 | kota belud
# Processing Record 15 of Set 3 | ixtapa
# Processing Record 16 of Set 3 | ostrovnoy
# Processing Record 17 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 18 of Set 3 | georgetown
# Processing Record 19 of Set 3 | vanimo
# Processing Record 20 of Set 3 | pitimbu
# Processing Record 21 of Set 3 | metro
# Processing Record 22 of Set 3 | kodiak
# Processing Record 23 of Set 3 | balabac
# Processing Record 24 of Set 3 | severnyy
# Processing Record 25 of Set 3 | taksimo
# Processing Record 26 of Set 3 | waipawa
# Processing Record 27 of Set 3 | wajir
# Processing Record 28 of Set 3 | sao filipe
# Processing Record 29 of Set 3 | cidreira
# Processing Record 30 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 31 of Set 3 | alice springs
# Processing Record 32 of Set 3 | bubaque
# Processing Record 33 of Set 3 | gouyave
# Processing Record 34 of Set 3 | fortuna
# Processing Record 35 of Set 3 | mogadishu
# Processing Record 36 of Set 3 | riachao do jacuipe
# Processing Record 37 of Set 3 | qorveh
# Processing Record 38 of Set 3 | lata
# Processing Record 39 of Set 3 | muriti
# Processing Record 40 of Set 3 | srednekolymsk
# Processing Record 41 of Set 3 | dhuburi
# Processing Record 42 of Set 3 | cabadiangan
# Processing Record 43 of Set 3 | labuhan
# Processing Record 44 of Set 3 | stuttgart
# Processing Record 45 of Set 3 | felidhoo
# City not found. Skipping...
# Processing Record 46 of Set 3 | cabo san lucas
# Processing Record 47 of Set 3 | khatanga
# Processing Record 48 of Set 3 | sola
# Processing Record 49 of Set 3 | viligili
# City not found. Skipping...
# Processing Record 50 of Set 3 | upernavik
# Processing Record 1 of Set 4 | uchiza
# Processing Record 2 of Set 4 | oistins
# Processing Record 3 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 4 of Set 4 | port lincoln
# Processing Record 5 of Set 4 | saint-pierre
# Processing Record 6 of Set 4 | gorodovikovsk
# Processing Record 7 of Set 4 | ardakan
# Processing Record 8 of Set 4 | cockburn town
# Processing Record 9 of Set 4 | panzhihua
# Processing Record 10 of Set 4 | van
# Processing Record 11 of Set 4 | ambulu
# Processing Record 12 of Set 4 | mana
# Processing Record 13 of Set 4 | hilo
# Processing Record 14 of Set 4 | lorengau
# Processing Record 15 of Set 4 | jamestown
# Processing Record 16 of Set 4 | maningrida
# Processing Record 17 of Set 4 | klaksvik
# Processing Record 18 of Set 4 | lambarene
# Processing Record 19 of Set 4 | tasiilaq
# Processing Record 20 of Set 4 | loreto
# Processing Record 21 of Set 4 | nishihara
# Processing Record 22 of Set 4 | iwanai
# Processing Record 23 of Set 4 | lebu
# Processing Record 24 of Set 4 | torbay
# Processing Record 25 of Set 4 | malanje
# Processing Record 26 of Set 4 | husavik
# Processing Record 27 of Set 4 | kaoma
# Processing Record 28 of Set 4 | general pico
# Processing Record 29 of Set 4 | kahului
# Processing Record 30 of Set 4 | hambantota
# Processing Record 31 of Set 4 | ust-kuyga
# Processing Record 32 of Set 4 | nova olimpia
# Processing Record 33 of Set 4 | malangali
# Processing Record 34 of Set 4 | san quintin
# Processing Record 35 of Set 4 | shingu
# Processing Record 36 of Set 4 | santiago
# Processing Record 37 of Set 4 | viedma
# Processing Record 38 of Set 4 | chapleau
# Processing Record 39 of Set 4 | shunyi
# Processing Record 40 of Set 4 | satitoa
# City not found. Skipping...
# Processing Record 41 of Set 4 | ahipara
# Processing Record 42 of Set 4 | plettenberg bay
# Processing Record 43 of Set 4 | media luna
# Processing Record 44 of Set 4 | cayenne
# Processing Record 45 of Set 4 | constitucion
# Processing Record 46 of Set 4 | aykhal
# Processing Record 47 of Set 4 | iqaluit
# Processing Record 48 of Set 4 | lasa
# Processing Record 49 of Set 4 | hefei
# Processing Record 50 of Set 4 | faanui
# Processing Record 1 of Set 5 | san luis
# Processing Record 2 of Set 5 | agirish
# Processing Record 3 of Set 5 | pevek
# Processing Record 4 of Set 5 | garachine
# Processing Record 5 of Set 5 | chase
# Processing Record 6 of Set 5 | vestmannaeyjar
# Processing Record 7 of Set 5 | itaituba
# Processing Record 8 of Set 5 | choma
# Processing Record 9 of Set 5 | rocha
# Processing Record 10 of Set 5 | nuuk
# Processing Record 11 of Set 5 | pisco
# Processing Record 12 of Set 5 | wencheng
# Processing Record 13 of Set 5 | tiksi
# Processing Record 14 of Set 5 | saint anthony
# Processing Record 15 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 16 of Set 5 | middle island
# Processing Record 17 of Set 5 | canto do buriti
# Processing Record 18 of Set 5 | saint-augustin
# Processing Record 19 of Set 5 | kavaratti
# Processing Record 20 of Set 5 | amapa
# Processing Record 21 of Set 5 | svetlogorsk
# Processing Record 22 of Set 5 | hasaki
# Processing Record 23 of Set 5 | puerto leguizamo
# Processing Record 24 of Set 5 | jiangyou
# Processing Record 25 of Set 5 | codrington
# Processing Record 26 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 27 of Set 5 | sao joao da barra
# Processing Record 28 of Set 5 | marapanim
# Processing Record 29 of Set 5 | chittaurgarh
# Processing Record 30 of Set 5 | la cruz
# Processing Record 31 of Set 5 | guamuchil
# Processing Record 32 of Set 5 | asfi
# Processing Record 33 of Set 5 | kenora
# Processing Record 34 of Set 5 | vardo
# Processing Record 35 of Set 5 | klaeng
# Processing Record 36 of Set 5 | napier
# Processing Record 37 of Set 5 | tura
# Processing Record 38 of Set 5 | malinyi
# Processing Record 39 of Set 5 | lewiston
# Processing Record 40 of Set 5 | pemangkat
# Processing Record 41 of Set 5 | saskylakh
# Processing Record 42 of Set 5 | severo-kurilsk
# Processing Record 43 of Set 5 | bilibino
# Processing Record 44 of Set 5 | puerto escondido
# Processing Record 45 of Set 5 | port blair
# Processing Record 46 of Set 5 | grindavik
# Processing Record 47 of Set 5 | sabha
# Processing Record 48 of Set 5 | presidente medici
# Processing Record 49 of Set 5 | shahreza
# Processing Record 50 of Set 5 | slave lake
# Processing Record 1 of Set 6 | derzhavinsk
# Processing Record 2 of Set 6 | east london
# Processing Record 3 of Set 6 | airai
# Processing Record 4 of Set 6 | indiaroba
# Processing Record 5 of Set 6 | moron
# Processing Record 6 of Set 6 | saint george
# Processing Record 7 of Set 6 | tamandare
# Processing Record 8 of Set 6 | takoradi
# Processing Record 9 of Set 6 | khasan
# Processing Record 10 of Set 6 | nouadhibou
# Processing Record 11 of Set 6 | talnakh
# Processing Record 12 of Set 6 | comodoro rivadavia
# Processing Record 13 of Set 6 | walvis bay
# Processing Record 14 of Set 6 | nanortalik
# Processing Record 15 of Set 6 | chapais
# Processing Record 16 of Set 6 | kruisfontein
# Processing Record 17 of Set 6 | sao felix do xingu
# Processing Record 18 of Set 6 | westport
# Processing Record 19 of Set 6 | agadir
# Processing Record 20 of Set 6 | iglesias
# Processing Record 21 of Set 6 | harper
# Processing Record 22 of Set 6 | turukhansk
# Processing Record 23 of Set 6 | bulgan
# Processing Record 24 of Set 6 | cholet
# Processing Record 25 of Set 6 | mutis
# Processing Record 26 of Set 6 | mardin
# Processing Record 27 of Set 6 | utiroa
# City not found. Skipping...
# Processing Record 28 of Set 6 | hondo
# Processing Record 29 of Set 6 | shangqiu
# Processing Record 30 of Set 6 | marzuq
# Processing Record 31 of Set 6 | carutapera
# Processing Record 32 of Set 6 | noumea
# Processing Record 33 of Set 6 | upala
# Processing Record 34 of Set 6 | iisalmi
# Processing Record 35 of Set 6 | tazmalt
# Processing Record 36 of Set 6 | storm lake
# Processing Record 37 of Set 6 | tabas
# Processing Record 38 of Set 6 | kolyvan
# Processing Record 39 of Set 6 | bolshoy uluy
# City not found. Skipping...
# Processing Record 40 of Set 6 | paamiut
# Processing Record 41 of Set 6 | aswan
# Processing Record 42 of Set 6 | xining
# Processing Record 43 of Set 6 | buala
# Processing Record 44 of Set 6 | college
# Processing Record 45 of Set 6 | collie
# Processing Record 46 of Set 6 | mahanje
# Processing Record 47 of Set 6 | thinadhoo
# Processing Record 48 of Set 6 | namibe
# Processing Record 49 of Set 6 | hvolsvollur
# Processing Record 50 of Set 6 | bandarbeyla
# Processing Record 1 of Set 7 | kurilsk
# Processing Record 2 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 3 of Set 7 | pedro ii
# Processing Record 4 of Set 7 | iralaya
# Processing Record 5 of Set 7 | sao paulo de olivenca
# Processing Record 6 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 7 of Set 7 | katherine
# Processing Record 8 of Set 7 | hofn
# Processing Record 9 of Set 7 | laurel
# Processing Record 10 of Set 7 | genhe
# Processing Record 11 of Set 7 | narsaq
# Processing Record 12 of Set 7 | shaunavon
# Processing Record 13 of Set 7 | yuli
# Processing Record 14 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 15 of Set 7 | uravakonda
# Processing Record 16 of Set 7 | celestun
# Processing Record 17 of Set 7 | jumla
# Processing Record 18 of Set 7 | avera
# Processing Record 19 of Set 7 | yazman
# Processing Record 20 of Set 7 | coulihaut
# City not found. Skipping...
# Processing Record 21 of Set 7 | feltre
# Processing Record 22 of Set 7 | murwillumbah
# Processing Record 23 of Set 7 | vittoria
# Processing Record 24 of Set 7 | basco
# Processing Record 25 of Set 7 | pirovskoye
# Processing Record 26 of Set 7 | cherskiy
# Processing Record 27 of Set 7 | arica
# Processing Record 28 of Set 7 | mahebourg
# Processing Record 29 of Set 7 | anjozorobe
# Processing Record 30 of Set 7 | tunduru
# City not found. Skipping...
# Processing Record 31 of Set 7 | mopti
# Processing Record 32 of Set 7 | kibaha
# Processing Record 33 of Set 7 | salina
# Processing Record 34 of Set 7 | high level
# Processing Record 35 of Set 7 | arman
# Processing Record 36 of Set 7 | buchanan
# Processing Record 37 of Set 7 | balimo
# City not found. Skipping...
# Processing Record 38 of Set 7 | rio gallegos
# Processing Record 39 of Set 7 | sahrak
# City not found. Skipping...
# Processing Record 40 of Set 7 | lawrenceburg
# Processing Record 41 of Set 7 | kabalo
# Processing Record 42 of Set 7 | naze
# Processing Record 43 of Set 7 | quzhou
# Processing Record 44 of Set 7 | bokoro
# Processing Record 45 of Set 7 | tommot
# Processing Record 46 of Set 7 | krasnyy chikoy
# Processing Record 47 of Set 7 | picayune
# Processing Record 48 of Set 7 | biak
# Processing Record 49 of Set 7 | los llanos de aridane
# Processing Record 50 of Set 7 | nevinnomyssk
# Processing Record 1 of Set 8 | tagusao
# Processing Record 2 of Set 8 | progreso
# Processing Record 3 of Set 8 | tromso
# Processing Record 4 of Set 8 | eyl
# Processing Record 5 of Set 8 | evensk
# Processing Record 6 of Set 8 | san cristobal
# Processing Record 7 of Set 8 | yaan
# Processing Record 8 of Set 8 | sangueya
# Processing Record 9 of Set 8 | bara
# Processing Record 10 of Set 8 | sao gabriel da cachoeira
# Processing Record 11 of Set 8 | karratha
# Processing Record 12 of Set 8 | kholmsk
# Processing Record 13 of Set 8 | sept-iles
# Processing Record 14 of Set 8 | orgun
# City not found. Skipping...
# Processing Record 15 of Set 8 | ponta delgada
# Processing Record 16 of Set 8 | atar
# Processing Record 17 of Set 8 | sunrise manor
# Processing Record 18 of Set 8 | sangar
# Processing Record 19 of Set 8 | dawlatabad
# Processing Record 20 of Set 8 | salalah
# Processing Record 21 of Set 8 | chiplun
# Processing Record 22 of Set 8 | beidao
# Processing Record 23 of Set 8 | bambous virieux
# Processing Record 24 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 25 of Set 8 | yeehaw junction
# City not found. Skipping...
# Processing Record 26 of Set 8 | richards bay
# Processing Record 27 of Set 8 | afua
# Processing Record 28 of Set 8 | doka
# Processing Record 29 of Set 8 | bozeman
# Processing Record 30 of Set 8 | hit
# Processing Record 31 of Set 8 | shelburne
# Processing Record 32 of Set 8 | port macquarie
# Processing Record 33 of Set 8 | ketchikan
# Processing Record 34 of Set 8 | visby
# Processing Record 35 of Set 8 | aborlan
# Processing Record 36 of Set 8 | catalao
# Processing Record 37 of Set 8 | awbari
# Processing Record 38 of Set 8 | buritis
# Processing Record 39 of Set 8 | burns lake
# Processing Record 40 of Set 8 | chifeng
# Processing Record 41 of Set 8 | shu
# Processing Record 42 of Set 8 | mumford
# Processing Record 43 of Set 8 | yomitan
# City not found. Skipping...
# Processing Record 44 of Set 8 | poshekhonye
# Processing Record 45 of Set 8 | westpunt
# City not found. Skipping...
# Processing Record 46 of Set 8 | majholi
# Processing Record 47 of Set 8 | qandahar
# City not found. Skipping...
# Processing Record 48 of Set 8 | half moon bay
# Processing Record 49 of Set 8 | bay roberts
# Processing Record 50 of Set 8 | front royal
# Processing Record 1 of Set 9 | cowra
# Processing Record 2 of Set 9 | baruun-urt
# Processing Record 3 of Set 9 | bokajan
# Processing Record 4 of Set 9 | wajima
# Processing Record 5 of Set 9 | lensk
# Processing Record 6 of Set 9 | victor harbor
# Processing Record 7 of Set 9 | kavieng
# Processing Record 8 of Set 9 | arlit
# Processing Record 9 of Set 9 | bend
# Processing Record 10 of Set 9 | bokspits
# City not found. Skipping...
# Processing Record 11 of Set 9 | buarcos
# Processing Record 12 of Set 9 | darnah
# Processing Record 13 of Set 9 | esperance
# Processing Record 14 of Set 9 | pandan
# Processing Record 15 of Set 9 | ouesso
# Processing Record 16 of Set 9 | aklavik
# Processing Record 17 of Set 9 | henties bay
# Processing Record 18 of Set 9 | jaque
# Processing Record 19 of Set 9 | lamu
# Processing Record 20 of Set 9 | ati
# Processing Record 21 of Set 9 | east wenatchee bench
# Processing Record 22 of Set 9 | zhangjiakou
# Processing Record 23 of Set 9 | pangkalanbuun
# Processing Record 24 of Set 9 | palizada
# Processing Record 25 of Set 9 | saint-louis
# Processing Record 26 of Set 9 | leshukonskoye
# Processing Record 27 of Set 9 | bonthe
# Processing Record 28 of Set 9 | ostuni
# Processing Record 29 of Set 9 | luderitz
# Processing Record 30 of Set 9 | tiarei
# Processing Record 31 of Set 9 | innisfail
# Processing Record 32 of Set 9 | kenai
# Processing Record 33 of Set 9 | fenelon falls
# Processing Record 34 of Set 9 | houma
# Processing Record 35 of Set 9 | mansa
# Processing Record 36 of Set 9 | puerto narino
# Processing Record 37 of Set 9 | sawtell
# Processing Record 38 of Set 9 | mecca
# Processing Record 39 of Set 9 | freeport
# Processing Record 40 of Set 9 | ilinskiy
# Processing Record 41 of Set 9 | najran
# Processing Record 42 of Set 9 | farnham
# Processing Record 43 of Set 9 | oloron-sainte-marie
# Processing Record 44 of Set 9 | clyde river
# Processing Record 45 of Set 9 | baijiantan
# Processing Record 46 of Set 9 | cap malheureux
# Processing Record 47 of Set 9 | poronaysk
# Processing Record 48 of Set 9 | sitka
# Processing Record 49 of Set 9 | guerrero negro
# Processing Record 50 of Set 9 | honiara
# Processing Record 1 of Set 10 | dig
# Processing Record 2 of Set 10 | mitsamiouli
# Processing Record 3 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 4 of Set 10 | dudinka
# Processing Record 5 of Set 10 | antigonish
# Processing Record 6 of Set 10 | de-kastri
# Processing Record 7 of Set 10 | sibolga
# Processing Record 8 of Set 10 | katima mulilo
# Processing Record 9 of Set 10 | beckley
# Processing Record 10 of Set 10 | sinnamary
# Processing Record 11 of Set 10 | kautokeino
# Processing Record 12 of Set 10 | nazilli
# Processing Record 13 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 14 of Set 10 | tambo
# Processing Record 15 of Set 10 | broome
# Processing Record 16 of Set 10 | quelimane
# Processing Record 17 of Set 10 | elk city
# Processing Record 18 of Set 10 | haslett
# Processing Record 19 of Set 10 | dharampuri
# Processing Record 20 of Set 10 | taicheng
# Processing Record 21 of Set 10 | tenosique
# Processing Record 22 of Set 10 | flin flon
# Processing Record 23 of Set 10 | saryshagan
# City not found. Skipping...
# Processing Record 24 of Set 10 | coihaique
# Processing Record 25 of Set 10 | nhulunbuy
# Processing Record 26 of Set 10 | the valley
# Processing Record 27 of Set 10 | pachino
# Processing Record 28 of Set 10 | bandeirantes
# Processing Record 29 of Set 10 | vao
# Processing Record 30 of Set 10 | ust-kulom
# Processing Record 31 of Set 10 | faya
# Processing Record 32 of Set 10 | andros town
# Processing Record 33 of Set 10 | serebryanyy bor
# Processing Record 34 of Set 10 | ouegoa
# Processing Record 35 of Set 10 | presidencia roque saenz pena
# Processing Record 36 of Set 10 | touros
# Processing Record 37 of Set 10 | profitis ilias
# Processing Record 38 of Set 10 | sajanan
# Processing Record 39 of Set 10 | amga
# Processing Record 40 of Set 10 | namatanai
# Processing Record 41 of Set 10 | aksarka
# Processing Record 42 of Set 10 | canaries
# Processing Record 43 of Set 10 | saint pete beach
# Processing Record 44 of Set 10 | san isidro
# Processing Record 45 of Set 10 | vilhena
# Processing Record 46 of Set 10 | zambezi
# Processing Record 47 of Set 10 | ribeira grande
# Processing Record 48 of Set 10 | joura
# Processing Record 49 of Set 10 | haines junction
# Processing Record 50 of Set 10 | san patricio
# Processing Record 1 of Set 11 | yeppoon
# Processing Record 2 of Set 11 | khorol
# Processing Record 3 of Set 11 | luanda
# Processing Record 4 of Set 11 | show low
# Processing Record 5 of Set 11 | santa cruz
# Processing Record 6 of Set 11 | yar-sale
# Processing Record 7 of Set 11 | itupiranga
# Processing Record 8 of Set 11 | manzanillo
# Processing Record 9 of Set 11 | samarai
# Processing Record 10 of Set 11 | esso
# Processing Record 11 of Set 11 | omsukchan
# Processing Record 12 of Set 11 | zhigansk
# Processing Record 13 of Set 11 | bardiyah
# Processing Record 14 of Set 11 | mawlaik
# Processing Record 15 of Set 11 | eureka
# Processing Record 16 of Set 11 | ossora
# Processing Record 17 of Set 11 | zhaodong
# Processing Record 18 of Set 11 | santa maria
# Processing Record 19 of Set 11 | zhaoyuan
# Processing Record 20 of Set 11 | birjand
# Processing Record 21 of Set 11 | broken hill
# Processing Record 22 of Set 11 | sedhiou
# Processing Record 23 of Set 11 | nago
# Processing Record 24 of Set 11 | oksfjord
# Processing Record 25 of Set 11 | kalmunai
# Processing Record 26 of Set 11 | banda aceh
# Processing Record 27 of Set 11 | ambilobe
# Processing Record 28 of Set 11 | dingle
# Processing Record 29 of Set 11 | pangnirtung
# Processing Record 30 of Set 11 | mehamn
# Processing Record 31 of Set 11 | nsunga
# Processing Record 32 of Set 11 | pedernales
# Processing Record 33 of Set 11 | oblivskaya
# Processing Record 34 of Set 11 | mufumbwe
# Processing Record 35 of Set 11 | hurghada
# Processing Record 36 of Set 11 | la ronge
# Processing Record 37 of Set 11 | burnie
# Processing Record 38 of Set 11 | kvitok
# Processing Record 39 of Set 11 | nemuro
# Processing Record 40 of Set 11 | cherdakly
# Processing Record 41 of Set 11 | pathein
# Processing Record 42 of Set 11 | porbandar
# Processing Record 43 of Set 11 | trinidad
# Processing Record 44 of Set 11 | okahandja
# Processing Record 45 of Set 11 | guilin
# Processing Record 46 of Set 11 | verkhnevilyuysk
# Processing Record 47 of Set 11 | tomra
# Processing Record 48 of Set 11 | poum
# Processing Record 49 of Set 11 | pierre
# Processing Record 50 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 1 of Set 12 | ha tinh
# Processing Record 2 of Set 12 | bolshiye uki
# City not found. Skipping...
# Processing Record 3 of Set 12 | sao miguel do araguaia
# Processing Record 4 of Set 12 | kudat
# Processing Record 5 of Set 12 | hurricane
# Processing Record 6 of Set 12 | marathon
# Processing Record 7 of Set 12 | barahona
# Processing Record 8 of Set 12 | pitkyaranta
# Processing Record 9 of Set 12 | rio verde de mato grosso
# Processing Record 10 of Set 12 | luau
# Processing Record 11 of Set 12 | macae
# Processing Record 12 of Set 12 | toppenish
# Processing Record 13 of Set 12 | sioux lookout
# Processing Record 14 of Set 12 | tilichiki
# Processing Record 15 of Set 12 | hamilton
# Processing Record 16 of Set 12 | itarema
# Processing Record 17 of Set 12 | marawi
# Processing Record 18 of Set 12 | maragogi
# Processing Record 19 of Set 12 | abu kamal
# Processing Record 20 of Set 12 | walajapet
# Processing Record 21 of Set 12 | yenagoa
# Processing Record 22 of Set 12 | basoko
# Processing Record 23 of Set 12 | stawell
# Processing Record 24 of Set 12 | sambava
# Processing Record 25 of Set 12 | saint-agapit
# Processing Record 26 of Set 12 | auki
# Processing Record 27 of Set 12 | solovetskiy
# City not found. Skipping...
# Processing Record 28 of Set 12 | valparaiso
# Processing Record 29 of Set 12 | nabire
# Processing Record 30 of Set 12 | caiaponia
# Processing Record 31 of Set 12 | port hedland
# Processing Record 32 of Set 12 | bryan
# Processing Record 33 of Set 12 | zhaotong
# Processing Record 34 of Set 12 | boda
# Processing Record 35 of Set 12 | pasuquin
# Processing Record 36 of Set 12 | usinsk
# Processing Record 37 of Set 12 | usogorsk
# Processing Record 38 of Set 12 | yulara
# Processing Record 39 of Set 12 | obidos
# Processing Record 40 of Set 12 | maralal
# Processing Record 41 of Set 12 | matara
# Processing Record 42 of Set 12 | mangai
# Processing Record 43 of Set 12 | alexandria
# Processing Record 44 of Set 12 | bograd
# Processing Record 45 of Set 12 | manzil tamim
# City not found. Skipping...
# Processing Record 46 of Set 12 | colares
# Processing Record 47 of Set 12 | oktyabrskiy
# Processing Record 48 of Set 12 | rawson
# Processing Record 49 of Set 12 | son la
# Processing Record 50 of Set 12 | cam ranh
# Processing Record 1 of Set 13 | manaure
# Processing Record 2 of Set 13 | kirakira
# Processing Record 3 of Set 13 | erzin
# Processing Record 4 of Set 13 | mattru
# Processing Record 5 of Set 13 | prince rupert
# Processing Record 6 of Set 13 | hualmay
# Processing Record 7 of Set 13 | split
# Processing Record 8 of Set 13 | bambanglipuro
# Processing Record 9 of Set 13 | jalu
# Processing Record 10 of Set 13 | gavle
# Processing Record 11 of Set 13 | langsa
# Processing Record 12 of Set 13 | balkanabat
# Processing Record 13 of Set 13 | khrebtovaya
# Processing Record 14 of Set 13 | maghama
# City not found. Skipping...
# Processing Record 15 of Set 13 | khandyga
# Processing Record 16 of Set 13 | sao lourenco
# Processing Record 17 of Set 13 | mbandaka
# Processing Record 18 of Set 13 | kano
# Processing Record 19 of Set 13 | edd
# Processing Record 20 of Set 13 | guarda
# Processing Record 21 of Set 13 | tailai
# Processing Record 22 of Set 13 | portland
# Processing Record 23 of Set 13 | chauk
# Processing Record 24 of Set 13 | san jose iturbide
# Processing Record 25 of Set 13 | cabedelo
# Processing Record 26 of Set 13 | young
# Processing Record 27 of Set 13 | axim
# Processing Record 28 of Set 13 | bagotville
# Processing Record 29 of Set 13 | makakilo city
# Processing Record 30 of Set 13 | lahaina
# Processing Record 31 of Set 13 | kirkland lake
# Processing Record 32 of Set 13 | hatta
# Processing Record 33 of Set 13 | boca do acre
# Processing Record 34 of Set 13 | hihifo
# City not found. Skipping...
# Processing Record 35 of Set 13 | pangody
# Processing Record 36 of Set 13 | monterey
# Processing Record 37 of Set 13 | egvekinot
# Processing Record 38 of Set 13 | olafsvik
# Processing Record 39 of Set 13 | araceli
# Processing Record 40 of Set 13 | dubbo
# Processing Record 41 of Set 13 | sinegorye
# Processing Record 42 of Set 13 | juneau
# Processing Record 43 of Set 13 | berea
# Processing Record 44 of Set 13 | klyuchevskiy
# Processing Record 45 of Set 13 | temerloh
# Processing Record 46 of Set 13 | inta
# Processing Record 47 of Set 13 | zanesville
# Processing Record 48 of Set 13 | ojinaga
# Processing Record 49 of Set 13 | itoman
# Processing Record 50 of Set 13 | siddipet
# Processing Record 1 of Set 14 | zyryanka
# Processing Record 2 of Set 14 | ngukurr
# City not found. Skipping...
# Processing Record 3 of Set 14 | manicore
# Processing Record 4 of Set 14 | sotara
# City not found. Skipping...
# Processing Record 5 of Set 14 | ilmajoki
# Processing Record 6 of Set 14 | sarakhs
# Processing Record 7 of Set 14 | palabuhanratu
# City not found. Skipping...
# Processing Record 8 of Set 14 | madison heights
# Processing Record 9 of Set 14 | wamba
# Processing Record 10 of Set 14 | kakogawa
# Processing Record 11 of Set 14 | paradwip
# City not found. Skipping...
# Processing Record 12 of Set 14 | dilla
# Processing Record 13 of Set 14 | coari
# Processing Record 14 of Set 14 | breves
# Processing Record 15 of Set 14 | saldanha
# Processing Record 16 of Set 14 | harlingen
# Processing Record 17 of Set 14 | valmiera
# Processing Record 18 of Set 14 | castle douglas
# Processing Record 19 of Set 14 | korla
# Processing Record 20 of Set 14 | kidodi
# Processing Record 21 of Set 14 | fort william
# Processing Record 22 of Set 14 | upington
# Processing Record 23 of Set 14 | samana
# Processing Record 24 of Set 14 | havre-saint-pierre
# Processing Record 25 of Set 14 | tessalit
# Processing Record 26 of Set 14 | kilmez
# City not found. Skipping...
# Processing Record 27 of Set 14 | marystown
# Processing Record 28 of Set 14 | esfarayen
# Processing Record 29 of Set 14 | laguna
# Processing Record 30 of Set 14 | wanning
# Processing Record 31 of Set 14 | asnaes
# Processing Record 32 of Set 14 | iraray
# Processing Record 33 of Set 14 | goundam
# Processing Record 34 of Set 14 | deputatskiy
# Processing Record 35 of Set 14 | mogapi
# Processing Record 36 of Set 14 | isla mujeres
# Processing Record 37 of Set 14 | holeby
# Processing Record 38 of Set 14 | privas
# Processing Record 39 of Set 14 | isugod
# Processing Record 40 of Set 14 | vigrestad
# Processing Record 41 of Set 14 | olonets
# Processing Record 42 of Set 14 | goure
# Processing Record 43 of Set 14 | sumbe
# Processing Record 44 of Set 14 | burgeo
# Processing Record 45 of Set 14 | iranshahr
# Processing Record 46 of Set 14 | sorland
# Processing Record 47 of Set 14 | fukue
# Processing Record 48 of Set 14 | karaton
# Processing Record 49 of Set 14 | lugo
# Processing Record 50 of Set 14 | tasbuget
# City not found. Skipping...
# Processing Record 1 of Set 15 | krasnoyarka
# Processing Record 2 of Set 15 | sao jose da coroa grande
# Processing Record 3 of Set 15 | mombetsu
# Processing Record 4 of Set 15 | kungurtug
# Processing Record 5 of Set 15 | bagnes
# Processing Record 6 of Set 15 | howard springs
# Processing Record 7 of Set 15 | kulhudhuffushi
# Processing Record 8 of Set 15 | san pedro
# Processing Record 9 of Set 15 | lanzhou
# Processing Record 10 of Set 15 | udachnyy
# Processing Record 11 of Set 15 | ozgon
# City not found. Skipping...
# Processing Record 12 of Set 15 | bogatyye saby
# Processing Record 13 of Set 15 | krynychky
# Processing Record 14 of Set 15 | kommunar
# Processing Record 15 of Set 15 | talas
# Processing Record 16 of Set 15 | surok
# Processing Record 17 of Set 15 | vila franca do campo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### 5) Add data to new DataFrame

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0         Ushuaia -54.80  -68.30     41.00        80          20        6.93
# 1        Conneaut  41.95  -80.55     69.80        64          90        6.80
# 2           Lagoa  39.05  -27.98     68.61        73          72       23.22
# 3          Albany  42.60  -73.97     73.99        64          34        0.72
# 4    Norman Wells  65.28 -126.83     55.40        54          75       10.29
# 5    Farmersville  36.30 -119.21    104.00        27           0        6.38
# 6         Rikitea -23.12 -134.97     73.42        84           0       12.62
# 7        Hermanus -34.42   19.23     55.00        82           5        1.01
# 8       Inhambane -23.86   35.38     67.50        68          45        5.79
# 9  Saint-Philippe -21.36   55.77     66.20        72          40        6.93
#
#   Country                 Date
# 0      AR  2020-09-06 23:01:01
# 1      US  2020-09-06 23:02:13
# 2      PT  2020-09-06 23:02:13
# 3      US  2020-09-06 23:02:14
# 4      CA  2020-09-06 23:02:14
# 5      US  2020-09-06 23:02:14
# 6      PF  2020-09-06 23:02:15
# 7      ZA  2020-09-06 23:02:15
# 8      MZ  2020-09-06 23:02:15
# 9      RE  2020-09-06 23:02:15

# %% [markdown]
# ### 6) export DataFrame as a CSV file & save it as WeatherPy_Database.csv in Weather_Database folder

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
